# %% [markdown]
# # IFCA baseline Notebook
# #### The reimplementation of IFCA baseline was carried out on Google Colab Pro
# #### We used the following codebase: https://github.com/jichan3751/ifca
# #### To reimplement, download, unzip and run the code like below:

# %%
! unzip ifca.zip
# %cd ifca/
# Out:
# Archive:  ifca.zip
#    creating: ifca/
#   inflating: ifca/.gitignore
#   inflating: ifca/README.md
#    creating: ifca/cifar/
#   inflating: ifca/cifar/README.md
#   inflating: ifca/cifar/cifar10.py
#   inflating: ifca/cifar/cifar10_eval.py
#   inflating: ifca/cifar/cifar10_input.py
#   inflating: ifca/cifar/cifar10_input_test.py
#   inflating: ifca/cifar/cifar10_multi_gpu_train.py
#   inflating: ifca/cifar/cifar10_train.py
#   inflating: ifca/cifar/config.json
#   inflating: ifca/cifar/process_runner.py
#   inflating: ifca/cifar/run.py
#   inflating: ifca/cifar/run.sh
#   inflating: ifca/cifar/train_cluster_cifar_tf.py
#   inflating: ifca/cifar/train_cluster_cifar_tf_local.py
#   inflating: ifca/cifar/train_cluster_cifar_tf_single.py
#   inflating: ifca/cifar/util.py
#    creating: ifca/femnist/
#   inflating: ifca/femnist/README.md
#    creating: ifca/femnist/fedavg_pretrain/
#    creating: ifca/femnist/fedavg_pretrain/data/
# ...

# %% [markdown]
# #### FashionMNIST (The code was reproduced from the source github repo and FashionMNIST was loaded instead of MNIST)

# %%
# %cd fashion-mnist/
! python train_cluster_mnist.py
# %cd ..
# Out:
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 0, 'train_seed': 0, 'project_dir': 'output', 'dataset_dir': 'output'}
# ...
# 100% 26421880/26421880 [00:03<00:00, 7449101.77it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 29515/29515 [00:00<00:00, 133141.12it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 4422102/4422102 [00:08<00:00, 520570.28it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 5148/5148 [00:00<00:00, 27825099.22it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Epoch -1 tr: l 2.294 a 0.108 clct[728, 9, 443, 20] 3.160sec
# Epoch -1 tst: l 2.294 a 0.110 clct[118, 3, 74, 5] 0.500sec
# ...

# %% [markdown]
# #### MNIST and Fashion-MNIST 10 for rounds experiments

# %%
# %cd mnist/
! python train_cluster_mnist.py
# %cd ..
# Out:
# /content/ifca/mnist
# config: {'m': 2400, 'm_test': 400, 'p': 4, 'n': 100, 'h1': 200, 'num_epochs': 10, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 0, 'train_seed': 0, 'project_dir': 'output', 'dataset_dir': 'output'}
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 9912422/9912422 [00:00<00:00, 55470300.37it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 28881/28881 [00:00<00:00, 1465132.55it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 13754947.66it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 4542/4542 [00:00<00:00, 13976910.32it/s]
# ...

# %%
# %cd fashion-mnist/
! python train_cluster_mnist.py
# %cd ..
# Out:
# /content/ifca/fashion-mnist
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'h1': 200, 'num_epochs': 10, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 0, 'train_seed': 0, 'project_dir': 'output', 'dataset_dir': 'output'}
# ...
# 100% 26421880/26421880 [00:01<00:00, 16293912.03it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 29515/29515 [00:00<00:00, 295298.13it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 4422102/4422102 [00:00<00:00, 5620348.83it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 5148/5148 [00:00<00:00, 29377247.61it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Epoch -1 tr: l 2.294 a 0.108 clct[728, 9, 443, 20] 3.140sec
# Epoch -1 tst: l 2.294 a 0.110 clct[118, 3, 74, 5] 0.515sec
# ...
