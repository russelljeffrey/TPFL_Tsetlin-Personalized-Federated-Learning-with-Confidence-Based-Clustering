# %% [markdown]
# # TPFL Experiment
# #### This notebook was implemented on Google Colab Pro.
# #### Use the following command to reimplement the TPFL experiments (Make sure the requirements are satisfied):
# #### `! python main.py --experiment {1 | 2 | 3 | 4 | 5) --dataset {mnist | fashion_mnist | emnist}`
# #### N.B.: Remove the ! mark if the main.py is not run in notebook cells.
# #### Set experiment to a number between 1 and 5 and set dataset to either `mnist`,`fashion_mnist` or `emnist`.
#
# #### Based on the the implemented experiments, at least 50 GB of RAM is required.

# %% [markdown]
# # Dependancies

# %%
! pip install tmu
! pip install tensorflow-probability
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # MNIST Experiment 1

# %%
! python main.py --experiment 1 --dataset mnist
# Out:
# 2024-08-13 19:09:40.069117: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-13 19:09:40.069288: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-13 19:09:40.127690: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-13 19:09:42,301 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-13 19:09:42,302 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 2 --dataset mnist
# Out:
# 2024-08-14 02:21:59.829325: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-14 02:21:59.829490: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-14 02:21:59.883851: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-14 02:22:02,042 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-14 02:22:02,042 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 3 --dataset mnist
# Out:
# 2024-08-14 13:24:35.514309: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-14 13:24:35.514495: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-14 13:24:35.565586: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-14 13:24:37,743 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-14 13:24:37,743 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 4 --dataset mnist
# Out:
# 2024-08-14 20:05:38.995006: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-14 20:05:38.995175: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-14 20:05:39.049454: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-14 20:05:41,287 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-14 20:05:41,287 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 5 --dataset mnist
# Out:
# 2024-08-16 06:25:06.135208: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-16 06:25:06.135409: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-16 06:25:06.186413: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-16 06:25:08,617 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-16 06:25:08,617 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 1 --dataset fashion_mnist
# Out:
# 2024-08-17 09:42:03.422934: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-17 09:42:03.423111: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-17 09:42:03.474243: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-17 09:42:05,786 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-17 09:42:05,786 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 2 --dataset fashion_mnist
# Out:
# 2024-08-18 03:49:28.686938: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-18 03:49:28.687162: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-18 03:49:28.743545: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-18 03:49:31,131 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-18 03:49:31,131 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 3 --dataset fashion_mnist
# Out:
# 2024-08-17 19:15:46.437472: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-17 19:15:46.437664: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-17 19:15:46.487954: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-17 19:15:48,873 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-17 19:15:48,874 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 4 --dataset fashion_mnist
# Out:
# 2024-08-18 14:44:27.315025: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-18 14:44:27.315181: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-18 14:44:27.376848: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-18 14:44:29,560 - tmu.util.cuda_profiler - WARNING - Could not import pycuda: No module named 'pycuda'
# 2024-08-18 14:44:29,560 - tmu.clause_bank.clause_bank_cuda - ERROR - No module named 'pycuda'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tmu/clause_bank/clause_bank_cuda.py", line 41, in <module>
# ...

# %%
! python main.py --experiment 5 --dataset fashion_mnist
# Out:
# 2024-08-28 16:10:39.677814: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-28 16:10:39.691486: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-28 16:10:39.695437: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-28 16:10:39.705236: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py --experiment 1 --dataset emnist
# Out:
# 2024-08-25 21:37:42.204787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-25 21:37:42.218547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-25 21:37:42.222534: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-25 21:37:42.232662: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py --experiment 2 --dataset emnist
# Out:
# 2024-08-26 19:15:00.960422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-26 19:15:00.985883: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-26 19:15:00.993345: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-26 19:15:01.012284: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py --experiment 3 --dataset emnist
# Out:
# 2024-08-27 17:09:25.698714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-27 17:09:25.724129: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-27 17:09:25.731201: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-27 17:09:25.748758: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py --experiment 4 --dataset emnist
# Out:
# 2024-08-29 07:47:13.319952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-29 07:47:13.333986: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-29 07:47:13.337961: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-29 07:47:13.347975: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py --experiment 5 --dataset emnist
# Out:
# 2024-08-28 19:29:38.371119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-28 19:29:38.390716: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-28 19:29:38.396674: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-28 19:29:38.409699: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
